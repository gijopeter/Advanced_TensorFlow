# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 869us/sample - loss: 251.7996 - y1_output_loss: 117.5238 - y2_output_loss: 131.9620 - y1_output_root_mean_squared_error: 10.8912 - y2_output_root_mean_squared_error: 11.5404 - val_loss: 36.2568 - val_y1_output_loss: 15.3052 - val_y2_output_loss: 22.0478 - val_y1_output_root_mean_squared_error: 3.8903 - val_y2_output_root_mean_squared_error: 4.5959
# Epoch 2/500
# 614/614 [==============================] - 0s 136us/sample - loss: 32.8764 - y1_output_loss: 13.3622 - y2_output_loss: 20.0049 - y1_output_root_mean_squared_error: 3.6253 - y2_output_root_mean_squared_error: 4.4423 - val_loss: 77.2155 - val_y1_output_loss: 18.3018 - val_y2_output_loss: 60.0153 - val_y1_output_root_mean_squared_error: 4.2974 - val_y2_output_root_mean_squared_error: 7.6647
# Epoch 3/500
# 614/614 [==============================] - 0s 126us/sample - loss: 23.2156 - y1_output_loss: 9.3470 - y2_output_loss: 13.6495 - y1_output_root_mean_squared_error: 3.0717 - y2_output_root_mean_squared_error: 3.7122 - val_loss: 24.9727 - val_y1_output_loss: 10.1963 - val_y2_output_loss: 14.8380 - val_y1_output_root_mean_squared_error: 3.2139 - val_y2_output_root_mean_squared_error: 3.8267
# Epoch 4/500
# 614/614 [==============================] - 0s 130us/sample - loss: 22.3627 - y1_output_loss: 9.0407 - y2_output_loss: 13.8484 - y1_output_root_mean_squared_error: 2.9910 - y2_output_root_mean_squared_error: 3.6629 - val_loss: 75.2422 - val_y1_output_loss: 19.2006 - val_y2_output_loss: 58.1655 - val_y1_output_root_mean_squared_error: 4.3398 - val_y2_output_root_mean_squared_error: 7.5106
# Epoch 5/500
# 614/614 [==============================] - 0s 130us/sample - loss: 26.1458 - y1_output_loss: 9.5844 - y2_output_loss: 16.5173 - y1_output_root_mean_squared_error: 3.0906 - y2_output_root_mean_squared_error: 4.0735 - val_loss: 49.6546 - val_y1_output_loss: 13.0211 - val_y2_output_loss: 37.0728 - val_y1_output_root_mean_squared_error: 3.6256 - val_y2_output_root_mean_squared_error: 6.0423
# Epoch 6/500
# 614/614 [==============================] - 0s 124us/sample - loss: 24.0408 - y1_output_loss: 8.8874 - y2_output_loss: 14.9961 - y1_output_root_mean_squared_error: 2.9880 - y2_output_root_mean_squared_error: 3.8875 - val_loss: 22.2905 - val_y1_output_loss: 9.2476 - val_y2_output_loss: 12.9507 - val_y1_output_root_mean_squared_error: 3.0707 - val_y2_output_root_mean_squared_error: 3.5863
# Epoch 7/500
# 614/614 [==============================] - 0s 123us/sample - loss: 19.2165 - y1_output_loss: 7.8518 - y2_output_loss: 11.3166 - y1_output_root_mean_squared_error: 2.8021 - y2_output_root_mean_squared_error: 3.3711 - val_loss: 42.0893 - val_y1_output_loss: 11.9932 - val_y2_output_loss: 30.7688 - val_y1_output_root_mean_squared_error: 3.4738 - val_y2_output_root_mean_squared_error: 5.4792
# Epoch 8/500
# 614/614 [==============================] - 0s 124us/sample - loss: 28.2821 - y1_output_loss: 9.7407 - y2_output_loss: 18.3118 - y1_output_root_mean_squared_error: 3.1307 - y2_output_root_mean_squared_error: 4.2989 - val_loss: 30.0789 - val_y1_output_loss: 11.1129 - val_y2_output_loss: 18.8853 - val_y1_output_root_mean_squared_error: 3.3679 - val_y2_output_root_mean_squared_error: 4.3285
# Epoch 9/500
# 614/614 [==============================] - 0s 128us/sample - loss: 22.7349 - y1_output_loss: 8.6080 - y2_output_loss: 14.0126 - y1_output_root_mean_squared_error: 2.9435 - y2_output_root_mean_squared_error: 3.7511 - val_loss: 27.5694 - val_y1_output_loss: 9.5669 - val_y2_output_loss: 17.8325 - val_y1_output_root_mean_squared_error: 3.1310 - val_y2_output_root_mean_squared_error: 4.2150
# Epoch 10/500
# 614/614 [==============================] - 0s 128us/sample - loss: 22.7728 - y1_output_loss: 8.3855 - y2_output_loss: 14.2166 - y1_output_root_mean_squared_error: 2.9075 - y2_output_root_mean_squared_error: 3.7841 - val_loss: 22.6990 - val_y1_output_loss: 9.6124 - val_y2_output_loss: 13.3390 - val_y1_output_root_mean_squared_error: 3.1137 - val_y2_output_root_mean_squared_error: 3.6061
# Epoch 11/500
# 614/614 [==============================] - 0s 126us/sample - loss: 20.7377 - y1_output_loss: 7.8703 - y2_output_loss: 12.8478 - y1_output_root_mean_squared_error: 2.8111 - y2_output_root_mean_squared_error: 3.5826 - val_loss: 21.8661 - val_y1_output_loss: 9.1508 - val_y2_output_loss: 12.6907 - val_y1_output_root_mean_squared_error: 3.0517 - val_y2_output_root_mean_squared_error: 3.5430
# Epoch 12/500
# 614/614 [==============================] - 0s 125us/sample - loss: 19.4070 - y1_output_loss: 7.6028 - y2_output_loss: 11.8316 - y1_output_root_mean_squared_error: 2.7529 - y2_output_root_mean_squared_error: 3.4393 - val_loss: 43.3074 - val_y1_output_loss: 13.8200 - val_y2_output_loss: 29.8521 - val_y1_output_root_mean_squared_error: 3.7347 - val_y2_output_root_mean_squared_error: 5.4184
# Epoch 13/500
# 614/614 [==============================] - 0s 123us/sample - loss: 19.1759 - y1_output_loss: 7.8169 - y2_output_loss: 11.2462 - y1_output_root_mean_squared_error: 2.8059 - y2_output_root_mean_squared_error: 3.3620 - val_loss: 23.2983 - val_y1_output_loss: 9.8133 - val_y2_output_loss: 13.1711 - val_y1_output_root_mean_squared_error: 3.1724 - val_y2_output_root_mean_squared_error: 3.6379
# Epoch 14/500
# 614/614 [==============================] - 0s 125us/sample - loss: 18.7460 - y1_output_loss: 7.6381 - y2_output_loss: 11.0520 - y1_output_root_mean_squared_error: 2.7736 - y2_output_root_mean_squared_error: 3.3246 - val_loss: 36.7652 - val_y1_output_loss: 10.9883 - val_y2_output_loss: 25.3538 - val_y1_output_root_mean_squared_error: 3.3627 - val_y2_output_root_mean_squared_error: 5.0455
# Epoch 15/500
# 614/614 [==============================] - 0s 128us/sample - loss: 20.1002 - y1_output_loss: 7.7891 - y2_output_loss: 12.1966 - y1_output_root_mean_squared_error: 2.8026 - y2_output_root_mean_squared_error: 3.4994 - val_loss: 27.2377 - val_y1_output_loss: 10.7629 - val_y2_output_loss: 16.2968 - val_y1_output_root_mean_squared_error: 3.3148 - val_y2_output_root_mean_squared_error: 4.0311
# Epoch 16/500
# 614/614 [==============================] - 0s 128us/sample - loss: 23.1712 - y1_output_loss: 8.2875 - y2_output_loss: 14.9388 - y1_output_root_mean_squared_error: 2.8718 - y2_output_root_mean_squared_error: 3.8631 - val_loss: 52.0974 - val_y1_output_loss: 14.7976 - val_y2_output_loss: 38.2364 - val_y1_output_root_mean_squared_error: 3.8463 - val_y2_output_root_mean_squared_error: 6.1077
# Epoch 17/500
# 614/614 [==============================] - 0s 128us/sample - loss: 20.1659 - y1_output_loss: 7.8409 - y2_output_loss: 12.2540 - y1_output_root_mean_squared_error: 2.8100 - y2_output_root_mean_squared_error: 3.5028 - val_loss: 25.2030 - val_y1_output_loss: 9.1138 - val_y2_output_loss: 16.1069 - val_y1_output_root_mean_squared_error: 3.0452 - val_y2_output_root_mean_squared_error: 3.9912
# Epoch 18/500
# 614/614 [==============================] - 0s 125us/sample - loss: 20.4062 - y1_output_loss: 7.7938 - y2_output_loss: 13.0237 - y1_output_root_mean_squared_error: 2.7635 - y2_output_root_mean_squared_error: 3.5734 - val_loss: 69.7703 - val_y1_output_loss: 19.2466 - val_y2_output_loss: 52.0757 - val_y1_output_root_mean_squared_error: 4.3712 - val_y2_output_root_mean_squared_error: 7.1178
# Epoch 19/500
# 614/614 [==============================] - 0s 123us/sample - loss: 17.7313 - y1_output_loss: 6.9972 - y2_output_loss: 10.8266 - y1_output_root_mean_squared_error: 2.6320 - y2_output_root_mean_squared_error: 3.2869 - val_loss: 35.3203 - val_y1_output_loss: 12.4960 - val_y2_output_loss: 23.4571 - val_y1_output_root_mean_squared_error: 3.5343 - val_y2_output_root_mean_squared_error: 4.7780
# Epoch 20/500
# 614/614 [==============================] - 0s 121us/sample - loss: 20.4046 - y1_output_loss: 7.7109 - y2_output_loss: 12.5932 - y1_output_root_mean_squared_error: 2.7780 - y2_output_root_mean_squared_error: 3.5619 - val_loss: 22.6367 - val_y1_output_loss: 9.9291 - val_y2_output_loss: 12.4563 - val_y1_output_root_mean_squared_error: 3.1928 - val_y2_output_root_mean_squared_error: 3.5274
# Epoch 21/500
# 614/614 [==============================] - 0s 122us/sample - loss: 16.2269 - y1_output_loss: 6.5541 - y2_output_loss: 9.6380 - y1_output_root_mean_squared_error: 2.5694 - y2_output_root_mean_squared_error: 3.1024 - val_loss: 24.2422 - val_y1_output_loss: 9.5488 - val_y2_output_loss: 14.7110 - val_y1_output_root_mean_squared_error: 3.1088 - val_y2_output_root_mean_squared_error: 3.8181
# Epoch 22/500
# 614/614 [==============================] - 0s 128us/sample - loss: 19.4064 - y1_output_loss: 7.5733 - y2_output_loss: 12.1731 - y1_output_root_mean_squared_error: 2.7150 - y2_output_root_mean_squared_error: 3.4691 - val_loss: 33.3171 - val_y1_output_loss: 9.7586 - val_y2_output_loss: 25.2181 - val_y1_output_root_mean_squared_error: 3.0826 - val_y2_output_root_mean_squared_error: 4.8800
# Epoch 23/500
# 614/614 [==============================] - 0s 127us/sample - loss: 17.1940 - y1_output_loss: 6.5715 - y2_output_loss: 10.5372 - y1_output_root_mean_squared_error: 2.5720 - y2_output_root_mean_squared_error: 3.2525 - val_loss: 21.6423 - val_y1_output_loss: 9.6614 - val_y2_output_loss: 12.2374 - val_y1_output_root_mean_squared_error: 3.1113 - val_y2_output_root_mean_squared_error: 3.4587
# Epoch 24/500
# 614/614 [==============================] - 0s 128us/sample - loss: 16.0666 - y1_output_loss: 6.3474 - y2_output_loss: 9.6271 - y1_output_root_mean_squared_error: 2.5274 - y2_output_root_mean_squared_error: 3.1111 - val_loss: 20.7176 - val_y1_output_loss: 9.2521 - val_y2_output_loss: 11.2953 - val_y1_output_root_mean_squared_error: 3.0684 - val_y2_output_root_mean_squared_error: 3.3620
# Epoch 25/500
# 614/614 [==============================] - 0s 129us/sample - loss: 14.8700 - y1_output_loss: 5.9303 - y2_output_loss: 8.9271 - y1_output_root_mean_squared_error: 2.4251 - y2_output_root_mean_squared_error: 2.9981 - val_loss: 18.8263 - val_y1_output_loss: 8.0416 - val_y2_output_loss: 10.8620 - val_y1_output_root_mean_squared_error: 2.8416 - val_y2_output_root_mean_squared_error: 3.2790
# Epoch 26/500
# 614/614 [==============================] - 0s 129us/sample - loss: 16.8689 - y1_output_loss: 6.3814 - y2_output_loss: 10.5629 - y1_output_root_mean_squared_error: 2.5207 - y2_output_root_mean_squared_error: 3.2427 - val_loss: 17.0988 - val_y1_output_loss: 6.8396 - val_y2_output_loss: 10.2772 - val_y1_output_root_mean_squared_error: 2.6334 - val_y2_output_root_mean_squared_error: 3.1881
# Epoch 27/500
# 614/614 [==============================] - 0s 130us/sample - loss: 14.0233 - y1_output_loss: 5.5949 - y2_output_loss: 8.4651 - y1_output_root_mean_squared_error: 2.3511 - y2_output_root_mean_squared_error: 2.9147 - val_loss: 19.2678 - val_y1_output_loss: 7.2886 - val_y2_output_loss: 11.7643 - val_y1_output_root_mean_squared_error: 2.7367 - val_y2_output_root_mean_squared_error: 3.4319
# Epoch 28/500
# 614/614 [==============================] - 0s 125us/sample - loss: 14.7714 - y1_output_loss: 5.9336 - y2_output_loss: 9.0252 - y1_output_root_mean_squared_error: 2.4126 - y2_output_root_mean_squared_error: 2.9918 - val_loss: 66.1041 - val_y1_output_loss: 20.1768 - val_y2_output_loss: 48.0988 - val_y1_output_root_mean_squared_error: 4.4386 - val_y2_output_root_mean_squared_error: 6.8120
# Epoch 29/500
# 614/614 [==============================] - 0s 129us/sample - loss: 15.0809 - y1_output_loss: 5.9830 - y2_output_loss: 8.9847 - y1_output_root_mean_squared_error: 2.4526 - y2_output_root_mean_squared_error: 3.0109 - val_loss: 16.2432 - val_y1_output_loss: 6.5960 - val_y2_output_loss: 9.3319 - val_y1_output_root_mean_squared_error: 2.6092 - val_y2_output_root_mean_squared_error: 3.0717
# Epoch 30/500
# 614/614 [==============================] - 0s 128us/sample - loss: 12.4963 - y1_output_loss: 5.0035 - y2_output_loss: 7.5709 - y1_output_root_mean_squared_error: 2.2248 - y2_output_root_mean_squared_error: 2.7471 - val_loss: 26.4991 - val_y1_output_loss: 9.3065 - val_y2_output_loss: 17.3042 - val_y1_output_root_mean_squared_error: 3.0680 - val_y2_output_root_mean_squared_error: 4.1336
# Epoch 31/500
# 614/614 [==============================] - 0s 126us/sample - loss: 13.6620 - y1_output_loss: 5.0987 - y2_output_loss: 8.7498 - y1_output_root_mean_squared_error: 2.2602 - y2_output_root_mean_squared_error: 2.9246 - val_loss: 21.9690 - val_y1_output_loss: 6.7191 - val_y2_output_loss: 15.4895 - val_y1_output_root_mean_squared_error: 2.6085 - val_y2_output_root_mean_squared_error: 3.8942
# Epoch 32/500
# 614/614 [==============================] - 0s 125us/sample - loss: 15.7087 - y1_output_loss: 5.7623 - y2_output_loss: 9.8247 - y1_output_root_mean_squared_error: 2.4085 - y2_output_root_mean_squared_error: 3.1477 - val_loss: 14.3537 - val_y1_output_loss: 5.6838 - val_y2_output_loss: 8.5591 - val_y1_output_root_mean_squared_error: 2.4138 - val_y2_output_root_mean_squared_error: 2.9202
# Epoch 33/500
# 614/614 [==============================] - 0s 123us/sample - loss: 14.0634 - y1_output_loss: 5.1638 - y2_output_loss: 8.8941 - y1_output_root_mean_squared_error: 2.2782 - y2_output_root_mean_squared_error: 2.9788 - val_loss: 18.2757 - val_y1_output_loss: 7.0820 - val_y2_output_loss: 10.7967 - val_y1_output_root_mean_squared_error: 2.7027 - val_y2_output_root_mean_squared_error: 3.3123
# Epoch 34/500
# 614/614 [==============================] - 0s 129us/sample - loss: 14.7051 - y1_output_loss: 5.5649 - y2_output_loss: 9.1102 - y1_output_root_mean_squared_error: 2.3482 - y2_output_root_mean_squared_error: 3.0317 - val_loss: 13.7796 - val_y1_output_loss: 5.7320 - val_y2_output_loss: 7.9140 - val_y1_output_root_mean_squared_error: 2.4276 - val_y2_output_root_mean_squared_error: 2.8083
# Epoch 35/500
# 614/614 [==============================] - 0s 124us/sample - loss: 11.3758 - y1_output_loss: 4.4961 - y2_output_loss: 6.8595 - y1_output_root_mean_squared_error: 2.1266 - y2_output_root_mean_squared_error: 2.6179 - val_loss: 17.2595 - val_y1_output_loss: 7.0486 - val_y2_output_loss: 9.7947 - val_y1_output_root_mean_squared_error: 2.6955 - val_y2_output_root_mean_squared_error: 3.1613
# Epoch 36/500
# 614/614 [==============================] - 0s 129us/sample - loss: 11.9614 - y1_output_loss: 4.5370 - y2_output_loss: 7.3470 - y1_output_root_mean_squared_error: 2.1316 - y2_output_root_mean_squared_error: 2.7235 - val_loss: 15.9175 - val_y1_output_loss: 7.2953 - val_y2_output_loss: 8.4653 - val_y1_output_root_mean_squared_error: 2.7202 - val_y2_output_root_mean_squared_error: 2.9185
# Epoch 37/500
# 614/614 [==============================] - 0s 122us/sample - loss: 15.8730 - y1_output_loss: 5.6229 - y2_output_loss: 10.4221 - y1_output_root_mean_squared_error: 2.3598 - y2_output_root_mean_squared_error: 3.2101 - val_loss: 25.0446 - val_y1_output_loss: 7.8810 - val_y2_output_loss: 17.8843 - val_y1_output_root_mean_squared_error: 2.7934 - val_y2_output_root_mean_squared_error: 4.1523
# Epoch 38/500
# 614/614 [==============================] - 0s 122us/sample - loss: 13.3247 - y1_output_loss: 5.0140 - y2_output_loss: 8.5595 - y1_output_root_mean_squared_error: 2.2206 - y2_output_root_mean_squared_error: 2.8972 - val_loss: 20.3466 - val_y1_output_loss: 8.3854 - val_y2_output_loss: 11.6509 - val_y1_output_root_mean_squared_error: 2.9314 - val_y2_output_root_mean_squared_error: 3.4284
# Epoch 39/500
# 614/614 [==============================] - 0s 123us/sample - loss: 12.1187 - y1_output_loss: 4.7540 - y2_output_loss: 7.5111 - y1_output_root_mean_squared_error: 2.1771 - y2_output_root_mean_squared_error: 2.7165 - val_loss: 18.5117 - val_y1_output_loss: 6.4258 - val_y2_output_loss: 12.4928 - val_y1_output_root_mean_squared_error: 2.5267 - val_y2_output_root_mean_squared_error: 3.4825
# Epoch 40/500
# 614/614 [==============================] - 0s 130us/sample - loss: 10.9474 - y1_output_loss: 4.0991 - y2_output_loss: 6.7731 - y1_output_root_mean_squared_error: 2.0331 - y2_output_root_mean_squared_error: 2.6103 - val_loss: 13.2719 - val_y1_output_loss: 4.7483 - val_y2_output_loss: 8.3826 - val_y1_output_root_mean_squared_error: 2.2070 - val_y2_output_root_mean_squared_error: 2.8984
# Epoch 41/500
# 614/614 [==============================] - 0s 124us/sample - loss: 11.6032 - y1_output_loss: 4.2404 - y2_output_loss: 7.2730 - y1_output_root_mean_squared_error: 2.0670 - y2_output_root_mean_squared_error: 2.7075 - val_loss: 14.5140 - val_y1_output_loss: 5.4198 - val_y2_output_loss: 9.0746 - val_y1_output_root_mean_squared_error: 2.3451 - val_y2_output_root_mean_squared_error: 3.0024
# Epoch 42/500
# 614/614 [==============================] - 0s 124us/sample - loss: 10.8035 - y1_output_loss: 3.9925 - y2_output_loss: 6.7110 - y1_output_root_mean_squared_error: 2.0076 - y2_output_root_mean_squared_error: 2.6025 - val_loss: 12.1473 - val_y1_output_loss: 4.7744 - val_y2_output_loss: 7.0583 - val_y1_output_root_mean_squared_error: 2.2201 - val_y2_output_root_mean_squared_error: 2.6867
# Epoch 43/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.6991 - y1_output_loss: 3.6987 - y2_output_loss: 5.9344 - y1_output_root_mean_squared_error: 1.9292 - y2_output_root_mean_squared_error: 2.4448 - val_loss: 14.7424 - val_y1_output_loss: 6.4061 - val_y2_output_loss: 8.3029 - val_y1_output_root_mean_squared_error: 2.5382 - val_y2_output_root_mean_squared_error: 2.8810
# Epoch 44/500
# 614/614 [==============================] - 0s 125us/sample - loss: 9.5937 - y1_output_loss: 3.7734 - y2_output_loss: 5.7561 - y1_output_root_mean_squared_error: 1.9492 - y2_output_root_mean_squared_error: 2.4071 - val_loss: 16.9875 - val_y1_output_loss: 5.2224 - val_y2_output_loss: 11.7778 - val_y1_output_root_mean_squared_error: 2.3007 - val_y2_output_root_mean_squared_error: 3.4197
# Epoch 45/500
# 614/614 [==============================] - 0s 154us/sample - loss: 13.1618 - y1_output_loss: 4.5509 - y2_output_loss: 8.5398 - y1_output_root_mean_squared_error: 2.1431 - y2_output_root_mean_squared_error: 2.9273 - val_loss: 10.9742 - val_y1_output_loss: 4.1041 - val_y2_output_loss: 6.8530 - val_y1_output_root_mean_squared_error: 2.0406 - val_y2_output_root_mean_squared_error: 2.6096
# Epoch 46/500
# 614/614 [==============================] - 0s 130us/sample - loss: 10.2206 - y1_output_loss: 3.4586 - y2_output_loss: 6.6847 - y1_output_root_mean_squared_error: 1.8657 - y2_output_root_mean_squared_error: 2.5961 - val_loss: 11.1760 - val_y1_output_loss: 3.9264 - val_y2_output_loss: 7.1366 - val_y1_output_root_mean_squared_error: 2.0103 - val_y2_output_root_mean_squared_error: 2.6711
# Epoch 47/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.0750 - y1_output_loss: 3.3767 - y2_output_loss: 5.7420 - y1_output_root_mean_squared_error: 1.8220 - y2_output_root_mean_squared_error: 2.3990 - val_loss: 13.1886 - val_y1_output_loss: 5.0431 - val_y2_output_loss: 8.2804 - val_y1_output_root_mean_squared_error: 2.2471 - val_y2_output_root_mean_squared_error: 2.8529
# Epoch 48/500
# 614/614 [==============================] - 0s 125us/sample - loss: 8.8672 - y1_output_loss: 3.2383 - y2_output_loss: 5.6383 - y1_output_root_mean_squared_error: 1.8041 - y2_output_root_mean_squared_error: 2.3691 - val_loss: 17.5150 - val_y1_output_loss: 5.5458 - val_y2_output_loss: 11.9678 - val_y1_output_root_mean_squared_error: 2.3731 - val_y2_output_root_mean_squared_error: 3.4472
# Epoch 49/500
# 614/614 [==============================] - 0s 124us/sample - loss: 8.0679 - y1_output_loss: 3.0490 - y2_output_loss: 5.0705 - y1_output_root_mean_squared_error: 1.7342 - y2_output_root_mean_squared_error: 2.2495 - val_loss: 22.9971 - val_y1_output_loss: 7.7336 - val_y2_output_loss: 15.5166 - val_y1_output_root_mean_squared_error: 2.7779 - val_y2_output_root_mean_squared_error: 3.9090
# Epoch 50/500
# 614/614 [==============================] - 0s 127us/sample - loss: 8.7589 - y1_output_loss: 3.0312 - y2_output_loss: 5.6495 - y1_output_root_mean_squared_error: 1.7490 - y2_output_root_mean_squared_error: 2.3874 - val_loss: 12.0228 - val_y1_output_loss: 4.3277 - val_y2_output_loss: 7.8421 - val_y1_output_root_mean_squared_error: 2.0820 - val_y2_output_root_mean_squared_error: 2.7728
# Epoch 51/500
# 614/614 [==============================] - 0s 124us/sample - loss: 7.5378 - y1_output_loss: 2.6828 - y2_output_loss: 4.8400 - y1_output_root_mean_squared_error: 1.6358 - y2_output_root_mean_squared_error: 2.2050 - val_loss: 10.1070 - val_y1_output_loss: 3.5049 - val_y2_output_loss: 6.5687 - val_y1_output_root_mean_squared_error: 1.8877 - val_y2_output_root_mean_squared_error: 2.5580
# Epoch 52/500
# 614/614 [==============================] - 0s 123us/sample - loss: 8.7564 - y1_output_loss: 3.0033 - y2_output_loss: 5.6960 - y1_output_root_mean_squared_error: 1.7369 - y2_output_root_mean_squared_error: 2.3957 - val_loss: 9.3251 - val_y1_output_loss: 3.7158 - val_y2_output_loss: 5.5580 - val_y1_output_root_mean_squared_error: 1.9451 - val_y2_output_root_mean_squared_error: 2.3541
# Epoch 53/500
# 614/614 [==============================] - 0s 123us/sample - loss: 7.3129 - y1_output_loss: 2.4704 - y2_output_loss: 4.7936 - y1_output_root_mean_squared_error: 1.5759 - y2_output_root_mean_squared_error: 2.1976 - val_loss: 8.2893 - val_y1_output_loss: 2.9231 - val_y2_output_loss: 5.1683 - val_y1_output_root_mean_squared_error: 1.7375 - val_y2_output_root_mean_squared_error: 2.2957
# Epoch 54/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.4237 - y1_output_loss: 2.7450 - y2_output_loss: 4.6508 - y1_output_root_mean_squared_error: 1.6611 - y2_output_root_mean_squared_error: 2.1597 - val_loss: 8.9153 - val_y1_output_loss: 2.5405 - val_y2_output_loss: 6.4344 - val_y1_output_root_mean_squared_error: 1.6159 - val_y2_output_root_mean_squared_error: 2.5108
# Epoch 55/500
# 614/614 [==============================] - 0s 125us/sample - loss: 8.3406 - y1_output_loss: 2.9312 - y2_output_loss: 5.4462 - y1_output_root_mean_squared_error: 1.7070 - y2_output_root_mean_squared_error: 2.3295 - val_loss: 14.0895 - val_y1_output_loss: 4.3432 - val_y2_output_loss: 9.9395 - val_y1_output_root_mean_squared_error: 2.0861 - val_y2_output_root_mean_squared_error: 3.1205
# Epoch 56/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.9970 - y1_output_loss: 2.3075 - y2_output_loss: 4.6672 - y1_output_root_mean_squared_error: 1.5196 - y2_output_root_mean_squared_error: 2.1651 - val_loss: 10.6447 - val_y1_output_loss: 3.3048 - val_y2_output_loss: 7.3879 - val_y1_output_root_mean_squared_error: 1.8250 - val_y2_output_root_mean_squared_error: 2.7045
# Epoch 57/500
# 614/614 [==============================] - 0s 123us/sample - loss: 6.7875 - y1_output_loss: 2.2124 - y2_output_loss: 4.5877 - y1_output_root_mean_squared_error: 1.4935 - y2_output_root_mean_squared_error: 2.1347 - val_loss: 21.1876 - val_y1_output_loss: 3.2060 - val_y2_output_loss: 18.1332 - val_y1_output_root_mean_squared_error: 1.8091 - val_y2_output_root_mean_squared_error: 4.2326
# Epoch 58/500
# 614/614 [==============================] - 0s 123us/sample - loss: 6.8428 - y1_output_loss: 2.3255 - y2_output_loss: 4.5410 - y1_output_root_mean_squared_error: 1.5170 - y2_output_root_mean_squared_error: 2.1311 - val_loss: 7.5732 - val_y1_output_loss: 2.8946 - val_y2_output_loss: 4.5873 - val_y1_output_root_mean_squared_error: 1.7134 - val_y2_output_root_mean_squared_error: 2.1534
# Epoch 59/500
# 614/614 [==============================] - 0s 121us/sample - loss: 6.7370 - y1_output_loss: 2.1416 - y2_output_loss: 4.6000 - y1_output_root_mean_squared_error: 1.4629 - y2_output_root_mean_squared_error: 2.1440 - val_loss: 11.2292 - val_y1_output_loss: 2.1309 - val_y2_output_loss: 9.0733 - val_y1_output_root_mean_squared_error: 1.4793 - val_y2_output_root_mean_squared_error: 3.0068
# Epoch 60/500
# 614/614 [==============================] - 0s 122us/sample - loss: 8.2042 - y1_output_loss: 2.5725 - y2_output_loss: 5.5954 - y1_output_root_mean_squared_error: 1.6113 - y2_output_root_mean_squared_error: 2.3681 - val_loss: 8.1398 - val_y1_output_loss: 2.5296 - val_y2_output_loss: 5.5040 - val_y1_output_root_mean_squared_error: 1.6115 - val_y2_output_root_mean_squared_error: 2.3543
# Epoch 61/500
# 614/614 [==============================] - 0s 122us/sample - loss: 6.4744 - y1_output_loss: 1.9014 - y2_output_loss: 4.6118 - y1_output_root_mean_squared_error: 1.3824 - y2_output_root_mean_squared_error: 2.1362 - val_loss: 9.5706 - val_y1_output_loss: 2.4019 - val_y2_output_loss: 7.1342 - val_y1_output_root_mean_squared_error: 1.5638 - val_y2_output_root_mean_squared_error: 2.6693
# Epoch 62/500
# 614/614 [==============================] - 0s 122us/sample - loss: 5.8030 - y1_output_loss: 1.7173 - y2_output_loss: 4.0922 - y1_output_root_mean_squared_error: 1.3160 - y2_output_root_mean_squared_error: 2.0177 - val_loss: 8.4518 - val_y1_output_loss: 2.2983 - val_y2_output_loss: 6.1122 - val_y1_output_root_mean_squared_error: 1.5280 - val_y2_output_root_mean_squared_error: 2.4732
# Epoch 63/500
# 614/614 [==============================] - 0s 122us/sample - loss: 6.7402 - y1_output_loss: 2.0072 - y2_output_loss: 4.6875 - y1_output_root_mean_squared_error: 1.4207 - y2_output_root_mean_squared_error: 2.1730 - val_loss: 11.3238 - val_y1_output_loss: 2.9355 - val_y2_output_loss: 8.2258 - val_y1_output_root_mean_squared_error: 1.7360 - val_y2_output_root_mean_squared_error: 2.8827
# Epoch 64/500
# 614/614 [==============================] - 0s 122us/sample - loss: 5.7470 - y1_output_loss: 1.9062 - y2_output_loss: 4.0273 - y1_output_root_mean_squared_error: 1.3541 - y2_output_root_mean_squared_error: 1.9782 - val_loss: 42.8783 - val_y1_output_loss: 17.4958 - val_y2_output_loss: 30.0918 - val_y1_output_root_mean_squared_error: 3.9570 - val_y2_output_root_mean_squared_error: 5.2173
# Epoch 65/500
# 614/614 [==============================] - 0s 124us/sample - loss: 8.6575 - y1_output_loss: 2.5874 - y2_output_loss: 6.0934 - y1_output_root_mean_squared_error: 1.6142 - y2_output_root_mean_squared_error: 2.4600 - val_loss: 9.9113 - val_y1_output_loss: 2.3558 - val_y2_output_loss: 7.6533 - val_y1_output_root_mean_squared_error: 1.5422 - val_y2_output_root_mean_squared_error: 2.7446
# Epoch 66/500
# 614/614 [==============================] - 0s 124us/sample - loss: 6.0853 - y1_output_loss: 1.6832 - y2_output_loss: 4.3735 - y1_output_root_mean_squared_error: 1.3002 - y2_output_root_mean_squared_error: 2.0964 - val_loss: 6.2041 - val_y1_output_loss: 1.9360 - val_y2_output_loss: 4.3292 - val_y1_output_root_mean_squared_error: 1.3833 - val_y2_output_root_mean_squared_error: 2.0714
# Epoch 67/500
# 614/614 [==============================] - 0s 124us/sample - loss: 5.8928 - y1_output_loss: 1.6921 - y2_output_loss: 4.2791 - y1_output_root_mean_squared_error: 1.2915 - y2_output_root_mean_squared_error: 2.0554 - val_loss: 19.5800 - val_y1_output_loss: 5.5486 - val_y2_output_loss: 14.2086 - val_y1_output_root_mean_squared_error: 2.3543 - val_y2_output_root_mean_squared_error: 3.7467
# Epoch 68/500
# 614/614 [==============================] - 0s 124us/sample - loss: 5.8032 - y1_output_loss: 1.6651 - y2_output_loss: 4.1286 - y1_output_root_mean_squared_error: 1.2828 - y2_output_root_mean_squared_error: 2.0390 - val_loss: 8.0406 - val_y1_output_loss: 1.9422 - val_y2_output_loss: 6.0727 - val_y1_output_root_mean_squared_error: 1.4078 - val_y2_output_root_mean_squared_error: 2.4615
# Epoch 69/500
# 614/614 [==============================] - 0s 124us/sample - loss: 5.6586 - y1_output_loss: 1.5467 - y2_output_loss: 4.0961 - y1_output_root_mean_squared_error: 1.2477 - y2_output_root_mean_squared_error: 2.0253 - val_loss: 6.7319 - val_y1_output_loss: 1.8872 - val_y2_output_loss: 4.7106 - val_y1_output_root_mean_squared_error: 1.3931 - val_y2_output_root_mean_squared_error: 2.1889
# Epoch 70/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.7884 - y1_output_loss: 1.6743 - y2_output_loss: 4.0935 - y1_output_root_mean_squared_error: 1.3001 - y2_output_root_mean_squared_error: 2.0244 - val_loss: 14.5182 - val_y1_output_loss: 3.1155 - val_y2_output_loss: 11.5122 - val_y1_output_root_mean_squared_error: 1.7708 - val_y2_output_root_mean_squared_error: 3.3738
# Epoch 71/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.2365 - y1_output_loss: 1.6191 - y2_output_loss: 4.7214 - y1_output_root_mean_squared_error: 1.2780 - y2_output_root_mean_squared_error: 2.1455 - val_loss: 19.4789 - val_y1_output_loss: 4.9077 - val_y2_output_loss: 14.3084 - val_y1_output_root_mean_squared_error: 2.2419 - val_y2_output_root_mean_squared_error: 3.8017
# Epoch 72/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.2772 - y1_output_loss: 1.1528 - y2_output_loss: 3.1007 - y1_output_root_mean_squared_error: 1.0749 - y2_output_root_mean_squared_error: 1.7669 - val_loss: 7.0450 - val_y1_output_loss: 1.9132 - val_y2_output_loss: 5.1774 - val_y1_output_root_mean_squared_error: 1.3828 - val_y2_output_root_mean_squared_error: 2.2656
# Epoch 73/500
# 614/614 [==============================] - 0s 123us/sample - loss: 4.6127 - y1_output_loss: 1.2405 - y2_output_loss: 3.3304 - y1_output_root_mean_squared_error: 1.1191 - y2_output_root_mean_squared_error: 1.8331 - val_loss: 4.9190 - val_y1_output_loss: 1.1577 - val_y2_output_loss: 3.7093 - val_y1_output_root_mean_squared_error: 1.0922 - val_y2_output_root_mean_squared_error: 1.9303
# Epoch 74/500
# 614/614 [==============================] - 0s 123us/sample - loss: 4.4179 - y1_output_loss: 1.2511 - y2_output_loss: 3.2285 - y1_output_root_mean_squared_error: 1.1183 - y2_output_root_mean_squared_error: 1.7797 - val_loss: 5.7618 - val_y1_output_loss: 1.3811 - val_y2_output_loss: 4.3341 - val_y1_output_root_mean_squared_error: 1.1916 - val_y2_output_root_mean_squared_error: 2.0837
# Epoch 75/500
# 614/614 [==============================] - 0s 124us/sample - loss: 5.7322 - y1_output_loss: 1.4829 - y2_output_loss: 4.1980 - y1_output_root_mean_squared_error: 1.2222 - y2_output_root_mean_squared_error: 2.0588 - val_loss: 4.7626 - val_y1_output_loss: 1.1671 - val_y2_output_loss: 3.4848 - val_y1_output_root_mean_squared_error: 1.0987 - val_y2_output_root_mean_squared_error: 1.8856
# Epoch 76/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.5299 - y1_output_loss: 1.5584 - y2_output_loss: 3.9352 - y1_output_root_mean_squared_error: 1.2532 - y2_output_root_mean_squared_error: 1.9898 - val_loss: 6.2070 - val_y1_output_loss: 1.3468 - val_y2_output_loss: 4.7568 - val_y1_output_root_mean_squared_error: 1.1807 - val_y2_output_root_mean_squared_error: 2.1939
# Epoch 77/500
# 614/614 [==============================] - 0s 121us/sample - loss: 4.4819 - y1_output_loss: 1.1257 - y2_output_loss: 3.3561 - y1_output_root_mean_squared_error: 1.0660 - y2_output_root_mean_squared_error: 1.8291 - val_loss: 5.2837 - val_y1_output_loss: 1.2303 - val_y2_output_loss: 3.9181 - val_y1_output_root_mean_squared_error: 1.1208 - val_y2_output_root_mean_squared_error: 2.0069
# Epoch 78/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.1464 - y1_output_loss: 1.2268 - y2_output_loss: 3.9481 - y1_output_root_mean_squared_error: 1.1083 - y2_output_root_mean_squared_error: 1.9794 - val_loss: 11.9844 - val_y1_output_loss: 2.6641 - val_y2_output_loss: 9.4421 - val_y1_output_root_mean_squared_error: 1.6326 - val_y2_output_root_mean_squared_error: 3.0527
# Epoch 79/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.8127 - y1_output_loss: 0.9891 - y2_output_loss: 2.8336 - y1_output_root_mean_squared_error: 0.9828 - y2_output_root_mean_squared_error: 1.6873 - val_loss: 7.7910 - val_y1_output_loss: 2.7547 - val_y2_output_loss: 4.8337 - val_y1_output_root_mean_squared_error: 1.6857 - val_y2_output_root_mean_squared_error: 2.2248
# Epoch 80/500
# 614/614 [==============================] - 0s 124us/sample - loss: 3.8644 - y1_output_loss: 0.9844 - y2_output_loss: 2.8996 - y1_output_root_mean_squared_error: 0.9935 - y2_output_root_mean_squared_error: 1.6963 - val_loss: 8.0197 - val_y1_output_loss: 2.1266 - val_y2_output_loss: 5.8536 - val_y1_output_root_mean_squared_error: 1.4601 - val_y2_output_root_mean_squared_error: 2.4265
# Epoch 81/500
# 614/614 [==============================] - 0s 124us/sample - loss: 4.7416 - y1_output_loss: 1.0667 - y2_output_loss: 3.6568 - y1_output_root_mean_squared_error: 1.0248 - y2_output_root_mean_squared_error: 1.9213 - val_loss: 5.0683 - val_y1_output_loss: 1.2886 - val_y2_output_loss: 3.7642 - val_y1_output_root_mean_squared_error: 1.1291 - val_y2_output_root_mean_squared_error: 1.9477
# Epoch 82/500
# 614/614 [==============================] - 0s 123us/sample - loss: 3.8417 - y1_output_loss: 0.9379 - y2_output_loss: 2.8960 - y1_output_root_mean_squared_error: 0.9709 - y2_output_root_mean_squared_error: 1.7027 - val_loss: 4.7293 - val_y1_output_loss: 1.0458 - val_y2_output_loss: 3.6732 - val_y1_output_root_mean_squared_error: 1.0280 - val_y2_output_root_mean_squared_error: 1.9164
# Epoch 83/500
# 614/614 [==============================] - 0s 123us/sample - loss: 3.7510 - y1_output_loss: 0.9610 - y2_output_loss: 2.9920 - y1_output_root_mean_squared_error: 0.9602 - y2_output_root_mean_squared_error: 1.6820 - val_loss: 43.3835 - val_y1_output_loss: 11.7240 - val_y2_output_loss: 30.9348 - val_y1_output_root_mean_squared_error: 3.4669 - val_y2_output_root_mean_squared_error: 5.6004
# Epoch 84/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.4408 - y1_output_loss: 1.5197 - y2_output_loss: 3.8866 - y1_output_root_mean_squared_error: 1.2346 - y2_output_root_mean_squared_error: 1.9790 - val_loss: 7.3378 - val_y1_output_loss: 1.5227 - val_y2_output_loss: 5.8825 - val_y1_output_root_mean_squared_error: 1.2289 - val_y2_output_root_mean_squared_error: 2.4140
# Epoch 85/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.1859 - y1_output_loss: 0.7452 - y2_output_loss: 2.4238 - y1_output_root_mean_squared_error: 0.8665 - y2_output_root_mean_squared_error: 1.5604 - val_loss: 4.5483 - val_y1_output_loss: 1.0831 - val_y2_output_loss: 3.4312 - val_y1_output_root_mean_squared_error: 1.0155 - val_y2_output_root_mean_squared_error: 1.8754
# Epoch 86/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.1102 - y1_output_loss: 0.8328 - y2_output_loss: 3.4518 - y1_output_root_mean_squared_error: 0.9151 - y2_output_root_mean_squared_error: 1.8091 - val_loss: 42.2968 - val_y1_output_loss: 5.5407 - val_y2_output_loss: 38.1154 - val_y1_output_root_mean_squared_error: 2.3095 - val_y2_output_root_mean_squared_error: 6.0797
# Epoch 87/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.6081 - y1_output_loss: 1.1300 - y2_output_loss: 3.5048 - y1_output_root_mean_squared_error: 1.0478 - y2_output_root_mean_squared_error: 1.8736 - val_loss: 5.3804 - val_y1_output_loss: 1.6671 - val_y2_output_loss: 3.6582 - val_y1_output_root_mean_squared_error: 1.2923 - val_y2_output_root_mean_squared_error: 1.9263
# Epoch 88/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.7216 - y1_output_loss: 0.8153 - y2_output_loss: 2.9458 - y1_output_root_mean_squared_error: 0.9066 - y2_output_root_mean_squared_error: 1.7029 - val_loss: 7.1622 - val_y1_output_loss: 1.0984 - val_y2_output_loss: 6.0851 - val_y1_output_root_mean_squared_error: 1.0574 - val_y2_output_root_mean_squared_error: 2.4585
# Epoch 89/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.3959 - y1_output_loss: 0.8972 - y2_output_loss: 3.5107 - y1_output_root_mean_squared_error: 0.9483 - y2_output_root_mean_squared_error: 1.8699 - val_loss: 8.4499 - val_y1_output_loss: 1.8475 - val_y2_output_loss: 6.6902 - val_y1_output_root_mean_squared_error: 1.3518 - val_y2_output_root_mean_squared_error: 2.5734
# Epoch 90/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.0867 - y1_output_loss: 0.7912 - y2_output_loss: 3.2601 - y1_output_root_mean_squared_error: 0.8925 - y2_output_root_mean_squared_error: 1.8139 - val_loss: 5.2427 - val_y1_output_loss: 0.8227 - val_y2_output_loss: 4.3535 - val_y1_output_root_mean_squared_error: 0.9199 - val_y2_output_root_mean_squared_error: 2.0968
# Epoch 91/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.1143 - y1_output_loss: 0.8813 - y2_output_loss: 3.1996 - y1_output_root_mean_squared_error: 0.9420 - y2_output_root_mean_squared_error: 1.7964 - val_loss: 4.7948 - val_y1_output_loss: 0.9774 - val_y2_output_loss: 3.6996 - val_y1_output_root_mean_squared_error: 1.0032 - val_y2_output_root_mean_squared_error: 1.9464
# Epoch 92/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.6379 - y1_output_loss: 0.8322 - y2_output_loss: 2.7779 - y1_output_root_mean_squared_error: 0.9159 - y2_output_root_mean_squared_error: 1.6730 - val_loss: 3.7998 - val_y1_output_loss: 0.5985 - val_y2_output_loss: 3.1311 - val_y1_output_root_mean_squared_error: 0.7815 - val_y2_output_root_mean_squared_error: 1.7858
# Epoch 93/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.1046 - y1_output_loss: 1.1386 - y2_output_loss: 3.9305 - y1_output_root_mean_squared_error: 1.0697 - y2_output_root_mean_squared_error: 1.9901 - val_loss: 5.5137 - val_y1_output_loss: 1.0785 - val_y2_output_loss: 4.4437 - val_y1_output_root_mean_squared_error: 1.0386 - val_y2_output_root_mean_squared_error: 2.1060
# Epoch 94/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.2393 - y1_output_loss: 0.6810 - y2_output_loss: 2.5770 - y1_output_root_mean_squared_error: 0.8277 - y2_output_root_mean_squared_error: 1.5982 - val_loss: 7.6343 - val_y1_output_loss: 1.2754 - val_y2_output_loss: 6.4498 - val_y1_output_root_mean_squared_error: 1.1147 - val_y2_output_root_mean_squared_error: 2.5282
# Epoch 95/500
# 614/614 [==============================] - 0s 125us/sample - loss: 4.2593 - y1_output_loss: 0.9707 - y2_output_loss: 3.2914 - y1_output_root_mean_squared_error: 0.9862 - y2_output_root_mean_squared_error: 1.8129 - val_loss: 4.2177 - val_y1_output_loss: 0.7112 - val_y2_output_loss: 3.4573 - val_y1_output_root_mean_squared_error: 0.8521 - val_y2_output_root_mean_squared_error: 1.8686
# Epoch 96/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.6155 - y1_output_loss: 0.8704 - y2_output_loss: 2.7574 - y1_output_root_mean_squared_error: 0.9173 - y2_output_root_mean_squared_error: 1.6656 - val_loss: 6.5885 - val_y1_output_loss: 1.7462 - val_y2_output_loss: 4.9953 - val_y1_output_root_mean_squared_error: 1.2841 - val_y2_output_root_mean_squared_error: 2.2226
# Epoch 97/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.4706 - y1_output_loss: 0.6663 - y2_output_loss: 2.7959 - y1_output_root_mean_squared_error: 0.8164 - y2_output_root_mean_squared_error: 1.6746 - val_loss: 6.1740 - val_y1_output_loss: 0.6575 - val_y2_output_loss: 5.6117 - val_y1_output_root_mean_squared_error: 0.8005 - val_y2_output_root_mean_squared_error: 2.3523
# Epoch 98/500
# 614/614 [==============================] - 0s 125us/sample - loss: 4.5448 - y1_output_loss: 0.9302 - y2_output_loss: 3.6317 - y1_output_root_mean_squared_error: 0.9655 - y2_output_root_mean_squared_error: 1.9007 - val_loss: 7.2550 - val_y1_output_loss: 1.0973 - val_y2_output_loss: 6.2289 - val_y1_output_root_mean_squared_error: 1.0436 - val_y2_output_root_mean_squared_error: 2.4831
# Epoch 99/500
# 614/614 [==============================] - 0s 123us/sample - loss: 3.4832 - y1_output_loss: 0.6559 - y2_output_loss: 2.8052 - y1_output_root_mean_squared_error: 0.8125 - y2_output_root_mean_squared_error: 1.6802 - val_loss: 3.9476 - val_y1_output_loss: 0.7436 - val_y2_output_loss: 3.1237 - val_y1_output_root_mean_squared_error: 0.8660 - val_y2_output_root_mean_squared_error: 1.7882
# Epoch 100/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.2670 - y1_output_loss: 0.8512 - y2_output_loss: 3.3867 - y1_output_root_mean_squared_error: 0.9235 - y2_output_root_mean_squared_error: 1.8477 - val_loss: 4.1831 - val_y1_output_loss: 0.6199 - val_y2_output_loss: 3.5096 - val_y1_output_root_mean_squared_error: 0.7972 - val_y2_output_root_mean_squared_error: 1.8835
# Epoch 101/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.8218 - y1_output_loss: 0.5529 - y2_output_loss: 2.3123 - y1_output_root_mean_squared_error: 0.7460 - y2_output_root_mean_squared_error: 1.5051 - val_loss: 10.3542 - val_y1_output_loss: 1.6668 - val_y2_output_loss: 9.2387 - val_y1_output_root_mean_squared_error: 1.2378 - val_y2_output_root_mean_squared_error: 2.9702
# Epoch 102/500
# 614/614 [==============================] - 0s 125us/sample - loss: 4.2917 - y1_output_loss: 0.9984 - y2_output_loss: 3.2690 - y1_output_root_mean_squared_error: 1.0031 - y2_output_root_mean_squared_error: 1.8126 - val_loss: 6.4671 - val_y1_output_loss: 0.7289 - val_y2_output_loss: 5.7201 - val_y1_output_root_mean_squared_error: 0.8655 - val_y2_output_root_mean_squared_error: 2.3912
# Epoch 103/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.1239 - y1_output_loss: 0.6047 - y2_output_loss: 2.5430 - y1_output_root_mean_squared_error: 0.7804 - y2_output_root_mean_squared_error: 1.5858 - val_loss: 7.9050 - val_y1_output_loss: 0.6873 - val_y2_output_loss: 7.2035 - val_y1_output_root_mean_squared_error: 0.8413 - val_y2_output_root_mean_squared_error: 2.6828
# Epoch 104/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.4886 - y1_output_loss: 0.6661 - y2_output_loss: 2.7962 - y1_output_root_mean_squared_error: 0.8178 - y2_output_root_mean_squared_error: 1.6792 - val_loss: 5.2266 - val_y1_output_loss: 1.0239 - val_y2_output_loss: 4.1710 - val_y1_output_root_mean_squared_error: 1.0089 - val_y2_output_root_mean_squared_error: 2.0515
# Epoch 105/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.7875 - y1_output_loss: 0.6069 - y2_output_loss: 2.2510 - y1_output_root_mean_squared_error: 0.7618 - y2_output_root_mean_squared_error: 1.4856 - val_loss: 24.4595 - val_y1_output_loss: 7.3532 - val_y2_output_loss: 18.1566 - val_y1_output_root_mean_squared_error: 2.6434 - val_y2_output_root_mean_squared_error: 4.1799
# Epoch 106/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.4159 - y1_output_loss: 0.7324 - y2_output_loss: 2.6554 - y1_output_root_mean_squared_error: 0.8594 - y2_output_root_mean_squared_error: 1.6363 - val_loss: 4.4255 - val_y1_output_loss: 0.7347 - val_y2_output_loss: 3.6489 - val_y1_output_root_mean_squared_error: 0.8545 - val_y2_output_root_mean_squared_error: 1.9223
# Epoch 107/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.3851 - y1_output_loss: 0.6113 - y2_output_loss: 2.7735 - y1_output_root_mean_squared_error: 0.7837 - y2_output_root_mean_squared_error: 1.6646 - val_loss: 3.9539 - val_y1_output_loss: 0.6775 - val_y2_output_loss: 3.2541 - val_y1_output_root_mean_squared_error: 0.8205 - val_y2_output_root_mean_squared_error: 1.8113
# Epoch 108/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.2447 - y1_output_loss: 0.6879 - y2_output_loss: 2.5404 - y1_output_root_mean_squared_error: 0.8333 - y2_output_root_mean_squared_error: 1.5970 - val_loss: 4.3349 - val_y1_output_loss: 0.7831 - val_y2_output_loss: 3.4691 - val_y1_output_root_mean_squared_error: 0.8904 - val_y2_output_root_mean_squared_error: 1.8820
# Epoch 109/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.8197 - y1_output_loss: 0.5955 - y2_output_loss: 2.2026 - y1_output_root_mean_squared_error: 0.7736 - y2_output_root_mean_squared_error: 1.4904 - val_loss: 3.9388 - val_y1_output_loss: 0.7481 - val_y2_output_loss: 3.1092 - val_y1_output_root_mean_squared_error: 0.8714 - val_y2_output_root_mean_squared_error: 1.7831
# Epoch 110/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.1043 - y1_output_loss: 0.6018 - y2_output_loss: 2.4777 - y1_output_root_mean_squared_error: 0.7782 - y2_output_root_mean_squared_error: 1.5807 - val_loss: 3.8357 - val_y1_output_loss: 0.6298 - val_y2_output_loss: 3.1484 - val_y1_output_root_mean_squared_error: 0.8005 - val_y2_output_root_mean_squared_error: 1.7874
# Epoch 111/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.7741 - y1_output_loss: 0.5562 - y2_output_loss: 2.1980 - y1_output_root_mean_squared_error: 0.7480 - y2_output_root_mean_squared_error: 1.4882 - val_loss: 3.7220 - val_y1_output_loss: 0.6002 - val_y2_output_loss: 3.0563 - val_y1_output_root_mean_squared_error: 0.7830 - val_y2_output_root_mean_squared_error: 1.7632
# Epoch 112/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.8459 - y1_output_loss: 0.5922 - y2_output_loss: 2.2567 - y1_output_root_mean_squared_error: 0.7613 - y2_output_root_mean_squared_error: 1.5055 - val_loss: 4.3761 - val_y1_output_loss: 0.9359 - val_y2_output_loss: 3.4215 - val_y1_output_root_mean_squared_error: 0.9619 - val_y2_output_root_mean_squared_error: 1.8576
# Epoch 113/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.6308 - y1_output_loss: 0.5122 - y2_output_loss: 2.1042 - y1_output_root_mean_squared_error: 0.7140 - y2_output_root_mean_squared_error: 1.4564 - val_loss: 3.8237 - val_y1_output_loss: 0.6856 - val_y2_output_loss: 3.1647 - val_y1_output_root_mean_squared_error: 0.8129 - val_y2_output_root_mean_squared_error: 1.7784
# Epoch 114/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.5697 - y1_output_loss: 0.5357 - y2_output_loss: 2.0838 - y1_output_root_mean_squared_error: 0.7270 - y2_output_root_mean_squared_error: 1.4287 - val_loss: 8.0415 - val_y1_output_loss: 1.6011 - val_y2_output_loss: 6.9181 - val_y1_output_root_mean_squared_error: 1.2081 - val_y2_output_root_mean_squared_error: 2.5655
# Epoch 115/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.9004 - y1_output_loss: 0.5957 - y2_output_loss: 2.2956 - y1_output_root_mean_squared_error: 0.7747 - y2_output_root_mean_squared_error: 1.5167 - val_loss: 3.8567 - val_y1_output_loss: 0.5777 - val_y2_output_loss: 3.2047 - val_y1_output_root_mean_squared_error: 0.7586 - val_y2_output_root_mean_squared_error: 1.8114
# Epoch 116/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.4932 - y1_output_loss: 0.4967 - y2_output_loss: 2.0051 - y1_output_root_mean_squared_error: 0.7037 - y2_output_root_mean_squared_error: 1.4135 - val_loss: 9.4817 - val_y1_output_loss: 1.6398 - val_y2_output_loss: 7.8765 - val_y1_output_root_mean_squared_error: 1.2775 - val_y2_output_root_mean_squared_error: 2.8017
# Epoch 117/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.8041 - y1_output_loss: 0.6235 - y2_output_loss: 2.2430 - y1_output_root_mean_squared_error: 0.7918 - y2_output_root_mean_squared_error: 1.4755 - val_loss: 6.1402 - val_y1_output_loss: 1.0402 - val_y2_output_loss: 5.2496 - val_y1_output_root_mean_squared_error: 0.9959 - val_y2_output_root_mean_squared_error: 2.2690
# Epoch 118/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.0572 - y1_output_loss: 0.5795 - y2_output_loss: 2.4857 - y1_output_root_mean_squared_error: 0.7636 - y2_output_root_mean_squared_error: 1.5729 - val_loss: 7.1961 - val_y1_output_loss: 0.8200 - val_y2_output_loss: 6.3712 - val_y1_output_root_mean_squared_error: 0.9100 - val_y2_output_root_mean_squared_error: 2.5235
# Epoch 119/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.6311 - y1_output_loss: 0.6213 - y2_output_loss: 2.0705 - y1_output_root_mean_squared_error: 0.7869 - y2_output_root_mean_squared_error: 1.4184 - val_loss: 6.5545 - val_y1_output_loss: 1.7148 - val_y2_output_loss: 4.9763 - val_y1_output_root_mean_squared_error: 1.2922 - val_y2_output_root_mean_squared_error: 2.2101
# Epoch 120/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 121us/sample - loss: 0.4619 - y1_output_loss: 0.1249 - y2_output_loss: 0.3334 - y1_output_root_mean_squared_error: 0.3551 - y2_output_root_mean_squared_error: 0.5795 - val_loss: 1.1211 - val_y1_output_loss: 0.2866 - val_y2_output_loss: 0.8115 - val_y1_output_root_mean_squared_error: 0.5285 - val_y2_output_root_mean_squared_error: 0.9175
# Epoch 462/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.5759 - y1_output_loss: 0.1321 - y2_output_loss: 0.4395 - y1_output_root_mean_squared_error: 0.3648 - y2_output_root_mean_squared_error: 0.6654 - val_loss: 1.1863 - val_y1_output_loss: 0.3840 - val_y2_output_loss: 0.8132 - val_y1_output_root_mean_squared_error: 0.5991 - val_y2_output_root_mean_squared_error: 0.9096
# Epoch 463/500
# 614/614 [==============================] - 0s 121us/sample - loss: 0.6603 - y1_output_loss: 0.1689 - y2_output_loss: 0.4855 - y1_output_root_mean_squared_error: 0.4127 - y2_output_root_mean_squared_error: 0.6999 - val_loss: 1.0096 - val_y1_output_loss: 0.2764 - val_y2_output_loss: 0.7163 - val_y1_output_root_mean_squared_error: 0.5197 - val_y2_output_root_mean_squared_error: 0.8600
# Epoch 464/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.4249 - y1_output_loss: 0.1240 - y2_output_loss: 0.3005 - y1_output_root_mean_squared_error: 0.3533 - y2_output_root_mean_squared_error: 0.5477 - val_loss: 1.2000 - val_y1_output_loss: 0.2732 - val_y2_output_loss: 0.9029 - val_y1_output_root_mean_squared_error: 0.5158 - val_y2_output_root_mean_squared_error: 0.9665
# Epoch 465/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.4544 - y1_output_loss: 0.1296 - y2_output_loss: 0.3225 - y1_output_root_mean_squared_error: 0.3616 - y2_output_root_mean_squared_error: 0.5689 - val_loss: 1.0987 - val_y1_output_loss: 0.3078 - val_y2_output_loss: 0.7833 - val_y1_output_root_mean_squared_error: 0.5471 - val_y2_output_root_mean_squared_error: 0.8941
# Epoch 466/500
# 614/614 [==============================] - 0s 121us/sample - loss: 0.8581 - y1_output_loss: 0.1916 - y2_output_loss: 0.6602 - y1_output_root_mean_squared_error: 0.4394 - y2_output_root_mean_squared_error: 0.8155 - val_loss: 1.0133 - val_y1_output_loss: 0.3107 - val_y2_output_loss: 0.6862 - val_y1_output_root_mean_squared_error: 0.5499 - val_y2_output_root_mean_squared_error: 0.8432
# Epoch 467/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4209 - y1_output_loss: 0.1222 - y2_output_loss: 0.2965 - y1_output_root_mean_squared_error: 0.3500 - y2_output_root_mean_squared_error: 0.5462 - val_loss: 0.9457 - val_y1_output_loss: 0.2534 - val_y2_output_loss: 0.6718 - val_y1_output_root_mean_squared_error: 0.5000 - val_y2_output_root_mean_squared_error: 0.8341
# Epoch 468/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3983 - y1_output_loss: 0.1203 - y2_output_loss: 0.2772 - y1_output_root_mean_squared_error: 0.3475 - y2_output_root_mean_squared_error: 0.5268 - val_loss: 1.0085 - val_y1_output_loss: 0.2648 - val_y2_output_loss: 0.7281 - val_y1_output_root_mean_squared_error: 0.5072 - val_y2_output_root_mean_squared_error: 0.8667
# Epoch 469/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3702 - y1_output_loss: 0.1181 - y2_output_loss: 0.2551 - y1_output_root_mean_squared_error: 0.3437 - y2_output_root_mean_squared_error: 0.5021 - val_loss: 0.9457 - val_y1_output_loss: 0.2905 - val_y2_output_loss: 0.6418 - val_y1_output_root_mean_squared_error: 0.5332 - val_y2_output_root_mean_squared_error: 0.8133
# Epoch 470/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4379 - y1_output_loss: 0.1297 - y2_output_loss: 0.3094 - y1_output_root_mean_squared_error: 0.3554 - y2_output_root_mean_squared_error: 0.5582 - val_loss: 1.0365 - val_y1_output_loss: 0.2851 - val_y2_output_loss: 0.7425 - val_y1_output_root_mean_squared_error: 0.5290 - val_y2_output_root_mean_squared_error: 0.8698
# Epoch 471/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3918 - y1_output_loss: 0.1346 - y2_output_loss: 0.2559 - y1_output_root_mean_squared_error: 0.3670 - y2_output_root_mean_squared_error: 0.5071 - val_loss: 0.9821 - val_y1_output_loss: 0.2848 - val_y2_output_loss: 0.6807 - val_y1_output_root_mean_squared_error: 0.5262 - val_y2_output_root_mean_squared_error: 0.8398
# Epoch 472/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.5138 - y1_output_loss: 0.1293 - y2_output_loss: 0.3830 - y1_output_root_mean_squared_error: 0.3606 - y2_output_root_mean_squared_error: 0.6195 - val_loss: 1.1468 - val_y1_output_loss: 0.3216 - val_y2_output_loss: 0.8153 - val_y1_output_root_mean_squared_error: 0.5552 - val_y2_output_root_mean_squared_error: 0.9157
# Epoch 473/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.7507 - y1_output_loss: 0.1817 - y2_output_loss: 0.5658 - y1_output_root_mean_squared_error: 0.4274 - y2_output_root_mean_squared_error: 0.7537 - val_loss: 1.0642 - val_y1_output_loss: 0.2933 - val_y2_output_loss: 0.7541 - val_y1_output_root_mean_squared_error: 0.5323 - val_y2_output_root_mean_squared_error: 0.8837
# Epoch 474/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4272 - y1_output_loss: 0.1242 - y2_output_loss: 0.3051 - y1_output_root_mean_squared_error: 0.3532 - y2_output_root_mean_squared_error: 0.5499 - val_loss: 1.2696 - val_y1_output_loss: 0.3796 - val_y2_output_loss: 0.8726 - val_y1_output_root_mean_squared_error: 0.6084 - val_y2_output_root_mean_squared_error: 0.9484
# Epoch 475/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3882 - y1_output_loss: 0.1125 - y2_output_loss: 0.2804 - y1_output_root_mean_squared_error: 0.3347 - y2_output_root_mean_squared_error: 0.5256 - val_loss: 1.6312 - val_y1_output_loss: 0.3309 - val_y2_output_loss: 1.3015 - val_y1_output_root_mean_squared_error: 0.5680 - val_y2_output_root_mean_squared_error: 1.1439
# Epoch 476/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.5269 - y1_output_loss: 0.1317 - y2_output_loss: 0.4000 - y1_output_root_mean_squared_error: 0.3640 - y2_output_root_mean_squared_error: 0.6280 - val_loss: 1.4649 - val_y1_output_loss: 0.2790 - val_y2_output_loss: 1.2182 - val_y1_output_root_mean_squared_error: 0.5183 - val_y2_output_root_mean_squared_error: 1.0937
# Epoch 477/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4849 - y1_output_loss: 0.1240 - y2_output_loss: 0.3598 - y1_output_root_mean_squared_error: 0.3534 - y2_output_root_mean_squared_error: 0.6000 - val_loss: 0.9040 - val_y1_output_loss: 0.2704 - val_y2_output_loss: 0.6177 - val_y1_output_root_mean_squared_error: 0.5138 - val_y2_output_root_mean_squared_error: 0.8000
# Epoch 478/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4322 - y1_output_loss: 0.1429 - y2_output_loss: 0.2875 - y1_output_root_mean_squared_error: 0.3794 - y2_output_root_mean_squared_error: 0.5369 - val_loss: 1.0484 - val_y1_output_loss: 0.2640 - val_y2_output_loss: 0.7641 - val_y1_output_root_mean_squared_error: 0.5084 - val_y2_output_root_mean_squared_error: 0.8888
# Epoch 479/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.4413 - y1_output_loss: 0.1453 - y2_output_loss: 0.2965 - y1_output_root_mean_squared_error: 0.3822 - y2_output_root_mean_squared_error: 0.5434 - val_loss: 1.2356 - val_y1_output_loss: 0.3135 - val_y2_output_loss: 0.8969 - val_y1_output_root_mean_squared_error: 0.5568 - val_y2_output_root_mean_squared_error: 0.9621
# Epoch 480/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.4859 - y1_output_loss: 0.1301 - y2_output_loss: 0.3519 - y1_output_root_mean_squared_error: 0.3622 - y2_output_root_mean_squared_error: 0.5956 - val_loss: 1.0528 - val_y1_output_loss: 0.4201 - val_y2_output_loss: 0.6352 - val_y1_output_root_mean_squared_error: 0.6341 - val_y2_output_root_mean_squared_error: 0.8066
# Epoch 481/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4337 - y1_output_loss: 0.1329 - y2_output_loss: 0.3080 - y1_output_root_mean_squared_error: 0.3628 - y2_output_root_mean_squared_error: 0.5496 - val_loss: 1.6487 - val_y1_output_loss: 0.2631 - val_y2_output_loss: 1.3859 - val_y1_output_root_mean_squared_error: 0.5134 - val_y2_output_root_mean_squared_error: 1.1769
# Epoch 482/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3844 - y1_output_loss: 0.1121 - y2_output_loss: 0.2708 - y1_output_root_mean_squared_error: 0.3343 - y2_output_root_mean_squared_error: 0.5221 - val_loss: 1.0945 - val_y1_output_loss: 0.2925 - val_y2_output_loss: 0.7863 - val_y1_output_root_mean_squared_error: 0.5381 - val_y2_output_root_mean_squared_error: 0.8972
# Epoch 483/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.4079 - y1_output_loss: 0.1374 - y2_output_loss: 0.2689 - y1_output_root_mean_squared_error: 0.3701 - y2_output_root_mean_squared_error: 0.5205 - val_loss: 0.9017 - val_y1_output_loss: 0.2673 - val_y2_output_loss: 0.6227 - val_y1_output_root_mean_squared_error: 0.5119 - val_y2_output_root_mean_squared_error: 0.7998
# Epoch 484/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3826 - y1_output_loss: 0.1112 - y2_output_loss: 0.2699 - y1_output_root_mean_squared_error: 0.3338 - y2_output_root_mean_squared_error: 0.5208 - val_loss: 0.9989 - val_y1_output_loss: 0.2624 - val_y2_output_loss: 0.7201 - val_y1_output_root_mean_squared_error: 0.5048 - val_y2_output_root_mean_squared_error: 0.8626
# Epoch 485/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.5930 - y1_output_loss: 0.1453 - y2_output_loss: 0.4430 - y1_output_root_mean_squared_error: 0.3823 - y2_output_root_mean_squared_error: 0.6685 - val_loss: 0.9380 - val_y1_output_loss: 0.2755 - val_y2_output_loss: 0.6543 - val_y1_output_root_mean_squared_error: 0.5196 - val_y2_output_root_mean_squared_error: 0.8173
# Epoch 486/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3784 - y1_output_loss: 0.1165 - y2_output_loss: 0.2601 - y1_output_root_mean_squared_error: 0.3403 - y2_output_root_mean_squared_error: 0.5124 - val_loss: 1.0094 - val_y1_output_loss: 0.3160 - val_y2_output_loss: 0.6732 - val_y1_output_root_mean_squared_error: 0.5581 - val_y2_output_root_mean_squared_error: 0.8355
# Epoch 487/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3823 - y1_output_loss: 0.1156 - y2_output_loss: 0.2772 - y1_output_root_mean_squared_error: 0.3395 - y2_output_root_mean_squared_error: 0.5168 - val_loss: 6.3226 - val_y1_output_loss: 0.9022 - val_y2_output_loss: 5.4106 - val_y1_output_root_mean_squared_error: 0.9489 - val_y2_output_root_mean_squared_error: 2.3286
# Epoch 488/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5998 - y1_output_loss: 0.1523 - y2_output_loss: 0.4436 - y1_output_root_mean_squared_error: 0.3906 - y2_output_root_mean_squared_error: 0.6688 - val_loss: 1.2004 - val_y1_output_loss: 0.2981 - val_y2_output_loss: 0.8941 - val_y1_output_root_mean_squared_error: 0.5368 - val_y2_output_root_mean_squared_error: 0.9551
# Epoch 489/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4117 - y1_output_loss: 0.1195 - y2_output_loss: 0.2951 - y1_output_root_mean_squared_error: 0.3447 - y2_output_root_mean_squared_error: 0.5412 - val_loss: 1.8638 - val_y1_output_loss: 0.4334 - val_y2_output_loss: 1.4223 - val_y1_output_root_mean_squared_error: 0.6518 - val_y2_output_root_mean_squared_error: 1.1996
# Epoch 490/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3764 - y1_output_loss: 0.1215 - y2_output_loss: 0.2573 - y1_output_root_mean_squared_error: 0.3499 - y2_output_root_mean_squared_error: 0.5040 - val_loss: 1.2427 - val_y1_output_loss: 0.3166 - val_y2_output_loss: 0.9155 - val_y1_output_root_mean_squared_error: 0.5487 - val_y2_output_root_mean_squared_error: 0.9704
# Epoch 491/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.5101 - y1_output_loss: 0.1420 - y2_output_loss: 0.3676 - y1_output_root_mean_squared_error: 0.3756 - y2_output_root_mean_squared_error: 0.6074 - val_loss: 1.1081 - val_y1_output_loss: 0.2850 - val_y2_output_loss: 0.8130 - val_y1_output_root_mean_squared_error: 0.5254 - val_y2_output_root_mean_squared_error: 0.9122
# Epoch 492/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4396 - y1_output_loss: 0.1222 - y2_output_loss: 0.3176 - y1_output_root_mean_squared_error: 0.3491 - y2_output_root_mean_squared_error: 0.5637 - val_loss: 1.1157 - val_y1_output_loss: 0.3043 - val_y2_output_loss: 0.8056 - val_y1_output_root_mean_squared_error: 0.5443 - val_y2_output_root_mean_squared_error: 0.9052
# Epoch 493/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4461 - y1_output_loss: 0.1253 - y2_output_loss: 0.3216 - y1_output_root_mean_squared_error: 0.3551 - y2_output_root_mean_squared_error: 0.5657 - val_loss: 1.1021 - val_y1_output_loss: 0.3224 - val_y2_output_loss: 0.7766 - val_y1_output_root_mean_squared_error: 0.5567 - val_y2_output_root_mean_squared_error: 0.8901
# Epoch 494/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3891 - y1_output_loss: 0.1154 - y2_output_loss: 0.2712 - y1_output_root_mean_squared_error: 0.3409 - y2_output_root_mean_squared_error: 0.5224 - val_loss: 1.2135 - val_y1_output_loss: 0.2830 - val_y2_output_loss: 0.9348 - val_y1_output_root_mean_squared_error: 0.5216 - val_y2_output_root_mean_squared_error: 0.9703
# Epoch 495/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3931 - y1_output_loss: 0.1143 - y2_output_loss: 0.2759 - y1_output_root_mean_squared_error: 0.3393 - y2_output_root_mean_squared_error: 0.5272 - val_loss: 0.9564 - val_y1_output_loss: 0.2761 - val_y2_output_loss: 0.6658 - val_y1_output_root_mean_squared_error: 0.5191 - val_y2_output_root_mean_squared_error: 0.8288
# Epoch 496/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3697 - y1_output_loss: 0.1094 - y2_output_loss: 0.2576 - y1_output_root_mean_squared_error: 0.3312 - y2_output_root_mean_squared_error: 0.5099 - val_loss: 0.9249 - val_y1_output_loss: 0.2576 - val_y2_output_loss: 0.6561 - val_y1_output_root_mean_squared_error: 0.4994 - val_y2_output_root_mean_squared_error: 0.8219
# Epoch 497/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3857 - y1_output_loss: 0.1310 - y2_output_loss: 0.2574 - y1_output_root_mean_squared_error: 0.3589 - y2_output_root_mean_squared_error: 0.5068 - val_loss: 1.0716 - val_y1_output_loss: 0.3076 - val_y2_output_loss: 0.7542 - val_y1_output_root_mean_squared_error: 0.5514 - val_y2_output_root_mean_squared_error: 0.8761
# Epoch 498/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.6204 - y1_output_loss: 0.1626 - y2_output_loss: 0.4638 - y1_output_root_mean_squared_error: 0.4033 - y2_output_root_mean_squared_error: 0.6766 - val_loss: 3.5166 - val_y1_output_loss: 0.5669 - val_y2_output_loss: 2.9646 - val_y1_output_root_mean_squared_error: 0.7448 - val_y2_output_root_mean_squared_error: 1.7210
# Epoch 499/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.9251 - y1_output_loss: 0.2037 - y2_output_loss: 0.7241 - y1_output_root_mean_squared_error: 0.4462 - y2_output_root_mean_squared_error: 0.8521 - val_loss: 1.6776 - val_y1_output_loss: 0.6511 - val_y2_output_loss: 1.1063 - val_y1_output_root_mean_squared_error: 0.7849 - val_y2_output_root_mean_squared_error: 1.0303
# Epoch 500/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4256 - y1_output_loss: 0.1307 - y2_output_loss: 0.2943 - y1_output_root_mean_squared_error: 0.3613 - y2_output_root_mean_squared_error: 0.5432 - val_loss: 1.3344 - val_y1_output_loss: 0.3725 - val_y2_output_loss: 0.9647 - val_y1_output_root_mean_squared_error: 0.5961 - val_y2_output_root_mean_squared_error: 0.9895

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 31us/sample - loss: 1.3344 - y1_output_loss: 0.3649 - y2_output_loss: 0.9754 - y1_output_root_mean_squared_error: 0.5961 - y2_output_root_mean_squared_error: 0.9895
# Loss = 1.3344242541820972, Y1_loss = 0.3649439513683319, Y1_mse = 0.5960713028907776, Y2_loss = 0.9754229784011841, Y2_mse = 0.9895065426826477

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
